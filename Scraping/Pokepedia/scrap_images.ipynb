# %%
import requests
from bs4 import BeautifulSoup

def get_pokemon_image(pokemon_name):
    url = f"https://www.pokepedia.fr/{pokemon_name}"
    
    response = requests.get(url)
    if response.status_code != 200:
        print(f"❌ Erreur {response.status_code} pour {pokemon_name}")
        return None
    
    soup = BeautifulSoup(response.text, "html.parser")

    # 🔍 Trouver l'image principale du Pokémon
    image_tag = soup.find("table", class_="tableaustandard").find("img")  # L’image est souvent la première <img>
    
    if image_tag:
        image_url = "https://www.pokepedia.fr" + image_tag["src"]  # Compléter l'URL si nécessaire
        return image_url
    else:
        print(f"⚠️ Aucune image trouvée pour {pokemon_name}")
        return None

# 🎯 Test avec Pikachu
image_url = get_pokemon_image("Rosélia")
print(f"URL de l'image de Pikachu : {image_url}")
# Out:
# URL de l'image de Pikachu : https://www.pokepedia.fr/images/thumb/b/ba/Ros%C3%A9lia-RS.png/250px-Ros%C3%A9lia-RS.png

# %%
import os 

def save_pokemon_image(pokemon_name):
    """Télécharge et enregistre l'image d'un Pokémon dans Data/images/."""
    image_url = get_pokemon_image(pokemon_name)
    
    if image_url:
        response = requests.get(image_url, stream=True)
        
        # 📂 Chemin d'enregistrement
        file_path = os.path.join("../../Data/images", f"{pokemon_name}.png")

        # 💾 Enregistrement de l'image
        with open(file_path, "wb") as file:
            for chunk in response.iter_content(1024):
                file.write(chunk)

        print(f"✅ Image enregistrée : {file_path}")
        return file_path
    else:
        print(f"❌ Échec du téléchargement pour {pokemon_name}")
        return None

# %%
#Test

save_pokemon_image("Pikachu")
# Out:
# ✅ Image enregistrée : ../../Data/images/Pikachu.png
# '../../Data/images/Pikachu.png'

# %%
import pandas as pd 

pokemon_all_gen = pd.read_csv("../../Data/pokemon_all_gen.csv")

# %%
for name in pokemon_all_gen["Noms"]:
    save_pokemon_image(name)
# Out:
# ✅ Image enregistrée : ../../Data/images/Bulbizarre.png
# ✅ Image enregistrée : ../../Data/images/Herbizarre.png
# ✅ Image enregistrée : ../../Data/images/Florizarre.png
# ✅ Image enregistrée : ../../Data/images/Salamèche.png
# ✅ Image enregistrée : ../../Data/images/Reptincel.png
# ✅ Image enregistrée : ../../Data/images/Dracaufeu.png
# ✅ Image enregistrée : ../../Data/images/Carapuce.png
# ✅ Image enregistrée : ../../Data/images/Carabaffe.png
# ✅ Image enregistrée : ../../Data/images/Tortank.png
# ✅ Image enregistrée : ../../Data/images/Chenipan.png
# ✅ Image enregistrée : ../../Data/images/Chrysacier.png
# ✅ Image enregistrée : ../../Data/images/Papilusion.png
# ✅ Image enregistrée : ../../Data/images/Aspicot.png
# ✅ Image enregistrée : ../../Data/images/Coconfort.png
# ✅ Image enregistrée : ../../Data/images/Dardargnan.png
# ✅ Image enregistrée : ../../Data/images/Roucool.png
# ✅ Image enregistrée : ../../Data/images/Roucoups.png
# ✅ Image enregistrée : ../../Data/images/Roucarnage.png
# ✅ Image enregistrée : ../../Data/images/Rattata.png
# ✅ Image enregistrée : ../../Data/images/Rattatac.png
# ✅ Image enregistrée : ../../Data/images/Piafabec.png
# ✅ Image enregistrée : ../../Data/images/Rapasdepic.png
# ✅ Image enregistrée : ../../Data/images/Abo.png
# ✅ Image enregistrée : ../../Data/images/Arbok.png
# ✅ Image enregistrée : ../../Data/images/Pikachu.png
# ✅ Image enregistrée : ../../Data/images/Raichu.png
# ✅ Image enregistrée : ../../Data/images/Sabelette.png
# ✅ Image enregistrée : ../../Data/images/Sablaireau.png
# ✅ Image enregistrée : ../../Data/images/Nidoran♀.png
# ✅ Image enregistrée : ../../Data/images/Nidorina.png
# ✅ Image enregistrée : ../../Data/images/Nidoqueen.png
# ✅ Image enregistrée : ../../Data/images/Nidoran♂.png
# ✅ Image enregistrée : ../../Data/images/Nidorino.png
# ✅ Image enregistrée : ../../Data/images/Nidoking.png
# ✅ Image enregistrée : ../../Data/images/Mélofée.png
# ✅ Image enregistrée : ../../Data/images/Mélodelfe.png
# ✅ Image enregistrée : ../../Data/images/Goupix.png
# ✅ Image enregistrée : ../../Data/images/Feunard.png
# ✅ Image enregistrée : ../../Data/images/Rondoudou.png
# ✅ Image enregistrée : ../../Data/images/Grodoudou.png
# ✅ Image enregistrée : ../../Data/images/Nosferapti.png
# ✅ Image enregistrée : ../../Data/images/Nosferalto.png
# ✅ Image enregistrée : ../../Data/images/Mystherbe.png
# ✅ Image enregistrée : ../../Data/images/Ortide.png
# ✅ Image enregistrée : ../../Data/images/Rafflesia.png
# ✅ Image enregistrée : ../../Data/images/Paras.png
# ✅ Image enregistrée : ../../Data/images/Parasect.png
# ✅ Image enregistrée : ../../Data/images/Mimitoss.png
# ✅ Image enregistrée : ../../Data/images/Aéromite.png
# ✅ Image enregistrée : ../../Data/images/Taupiqueur.png
# ✅ Image enregistrée : ../../Data/images/Triopikeur.png
# ✅ Image enregistrée : ../../Data/images/Miaouss.png
# ✅ Image enregistrée : ../../Data/images/Persian.png
# ✅ Image enregistrée : ../../Data/images/Psykokwak.png
# ✅ Image enregistrée : ../../Data/images/Akwakwak.png
# ✅ Image enregistrée : ../../Data/images/Férosinge.png
# ✅ Image enregistrée : ../../Data/images/Colossinge.png
# ✅ Image enregistrée : ../../Data/images/Caninos.png
# ✅ Image enregistrée : ../../Data/images/Arcanin.png
# ✅ Image enregistrée : ../../Data/images/Ptitard.png
# ✅ Image enregistrée : ../../Data/images/Têtarte.png
# ✅ Image enregistrée : ../../Data/images/Tartard.png
# ✅ Image enregistrée : ../../Data/images/Abra.png
# ✅ Image enregistrée : ../../Data/images/Kadabra.png
# ✅ Image enregistrée : ../../Data/images/Alakazam.png
# ✅ Image enregistrée : ../../Data/images/Machoc.png
# ✅ Image enregistrée : ../../Data/images/Machopeur.png
# ✅ Image enregistrée : ../../Data/images/Mackogneur.png
# ✅ Image enregistrée : ../../Data/images/Chétiflor.png
# ✅ Image enregistrée : ../../Data/images/Boustiflor.png
# ✅ Image enregistrée : ../../Data/images/Empiflor.png
# ✅ Image enregistrée : ../../Data/images/Tentacool.png
# ✅ Image enregistrée : ../../Data/images/Tentacruel.png
# ✅ Image enregistrée : ../../Data/images/Racaillou.png
# ✅ Image enregistrée : ../../Data/images/Gravalanch.png
# ✅ Image enregistrée : ../../Data/images/Grolem.png
# ✅ Image enregistrée : ../../Data/images/Ponyta.png
# ✅ Image enregistrée : ../../Data/images/Galopa.png
# ✅ Image enregistrée : ../../Data/images/Ramoloss.png
# ✅ Image enregistrée : ../../Data/images/Flagadoss.png
# ✅ Image enregistrée : ../../Data/images/Magnéti.png
# ✅ Image enregistrée : ../../Data/images/Magnéton.png
# ✅ Image enregistrée : ../../Data/images/Canarticho.png
# ✅ Image enregistrée : ../../Data/images/Doduo.png
# ✅ Image enregistrée : ../../Data/images/Dodrio.png
# ✅ Image enregistrée : ../../Data/images/Otaria.png
# ✅ Image enregistrée : ../../Data/images/Lamantine.png
# ✅ Image enregistrée : ../../Data/images/Tadmorv.png
# ✅ Image enregistrée : ../../Data/images/Grotadmorv.png
# ✅ Image enregistrée : ../../Data/images/Kokiyas.png
# ✅ Image enregistrée : ../../Data/images/Crustabri.png
# ✅ Image enregistrée : ../../Data/images/Fantominus.png
# ✅ Image enregistrée : ../../Data/images/Spectrum.png
# ✅ Image enregistrée : ../../Data/images/Ectoplasma.png
# ✅ Image enregistrée : ../../Data/images/Onix.png
# ✅ Image enregistrée : ../../Data/images/Soporifik.png
# ✅ Image enregistrée : ../../Data/images/Hypnomade.png
# ✅ Image enregistrée : ../../Data/images/Krabby.png
# ✅ Image enregistrée : ../../Data/images/Krabboss.png
# ✅ Image enregistrée : ../../Data/images/Voltorbe.png
# ✅ Image enregistrée : ../../Data/images/Électrode.png
# ✅ Image enregistrée : ../../Data/images/Noeunoeuf.png
# ✅ Image enregistrée : ../../Data/images/Noadkoko.png
# ✅ Image enregistrée : ../../Data/images/Osselait.png
# ✅ Image enregistrée : ../../Data/images/Ossatueur.png
# ✅ Image enregistrée : ../../Data/images/Kicklee.png
# ✅ Image enregistrée : ../../Data/images/Tygnon.png
# ✅ Image enregistrée : ../../Data/images/Excelangue.png
# ✅ Image enregistrée : ../../Data/images/Smogo.png
# ✅ Image enregistrée : ../../Data/images/Smogogo.png
# ✅ Image enregistrée : ../../Data/images/Rhinocorne.png
# ✅ Image enregistrée : ../../Data/images/Rhinoféros.png
# ✅ Image enregistrée : ../../Data/images/Leveinard.png
# ✅ Image enregistrée : ../../Data/images/Saquedeneu.png
# ✅ Image enregistrée : ../../Data/images/Kangourex.png
# ✅ Image enregistrée : ../../Data/images/Hypotrempe.png
# ✅ Image enregistrée : ../../Data/images/Hypocéan.png
# ✅ Image enregistrée : ../../Data/images/Poissirène.png
# ✅ Image enregistrée : ../../Data/images/Poissoroy.png
# ✅ Image enregistrée : ../../Data/images/Stari.png
# ✅ Image enregistrée : ../../Data/images/Staross.png
# ✅ Image enregistrée : ../../Data/images/M. Mime.png
# ✅ Image enregistrée : ../../Data/images/Insécateur.png
# ✅ Image enregistrée : ../../Data/images/Lippoutou.png
# ✅ Image enregistrée : ../../Data/images/Élektek.png
# ✅ Image enregistrée : ../../Data/images/Magmar.png
# ✅ Image enregistrée : ../../Data/images/Scarabrute.png
# ✅ Image enregistrée : ../../Data/images/Tauros.png
# ✅ Image enregistrée : ../../Data/images/Magicarpe.png
# ✅ Image enregistrée : ../../Data/images/Léviator.png
# ✅ Image enregistrée : ../../Data/images/Lokhlass.png
# ✅ Image enregistrée : ../../Data/images/Métamorph.png
# ✅ Image enregistrée : ../../Data/images/Évoli.png
# ✅ Image enregistrée : ../../Data/images/Aquali.png
# ✅ Image enregistrée : ../../Data/images/Voltali.png
# ✅ Image enregistrée : ../../Data/images/Pyroli.png
# ✅ Image enregistrée : ../../Data/images/Porygon.png
# ✅ Image enregistrée : ../../Data/images/Amonita.png
# ✅ Image enregistrée : ../../Data/images/Amonistar.png
# ✅ Image enregistrée : ../../Data/images/Kabuto.png
# ✅ Image enregistrée : ../../Data/images/Kabutops.png
# ✅ Image enregistrée : ../../Data/images/Ptéra.png
# ✅ Image enregistrée : ../../Data/images/Ronflex.png
# ✅ Image enregistrée : ../../Data/images/Artikodin.png
# ✅ Image enregistrée : ../../Data/images/Électhor.png
# ✅ Image enregistrée : ../../Data/images/Sulfura.png
# ✅ Image enregistrée : ../../Data/images/Minidraco.png
# ✅ Image enregistrée : ../../Data/images/Draco.png
# ✅ Image enregistrée : ../../Data/images/Dracolosse.png
# ✅ Image enregistrée : ../../Data/images/Mewtwo.png
# ✅ Image enregistrée : ../../Data/images/Mew.png
# ✅ Image enregistrée : ../../Data/images/Germignon.png
# ✅ Image enregistrée : ../../Data/images/Macronium.png
# ✅ Image enregistrée : ../../Data/images/Méganium.png
# ✅ Image enregistrée : ../../Data/images/Héricendre.png
# ✅ Image enregistrée : ../../Data/images/Feurisson.png
# ✅ Image enregistrée : ../../Data/images/Typhlosion.png
# ✅ Image enregistrée : ../../Data/images/Kaiminus.png
# ✅ Image enregistrée : ../../Data/images/Crocrodil.png
# ✅ Image enregistrée : ../../Data/images/Aligatueur.png
# ✅ Image enregistrée : ../../Data/images/Fouinette.png
# ✅ Image enregistrée : ../../Data/images/Fouinar.png
# ✅ Image enregistrée : ../../Data/images/Hoothoot.png
# ✅ Image enregistrée : ../../Data/images/Noarfang.png
# ✅ Image enregistrée : ../../Data/images/Coxy.png
# ✅ Image enregistrée : ../../Data/images/Coxyclaque.png
# ✅ Image enregistrée : ../../Data/images/Mimigal.png
# ✅ Image enregistrée : ../../Data/images/Migalos.png
# ✅ Image enregistrée : ../../Data/images/Nostenfer.png
# ✅ Image enregistrée : ../../Data/images/Loupio.png
# ✅ Image enregistrée : ../../Data/images/Lanturn.png
# ✅ Image enregistrée : ../../Data/images/Pichu.png
# ✅ Image enregistrée : ../../Data/images/Mélo.png
# ✅ Image enregistrée : ../../Data/images/Toudoudou.png
# ✅ Image enregistrée : ../../Data/images/Togepi.png
# ✅ Image enregistrée : ../../Data/images/Togetic.png
# ✅ Image enregistrée : ../../Data/images/Natu.png
# ✅ Image enregistrée : ../../Data/images/Xatu.png
# ✅ Image enregistrée : ../../Data/images/Wattouat.png
# ✅ Image enregistrée : ../../Data/images/Lainergie.png
# ✅ Image enregistrée : ../../Data/images/Pharamp.png
# ✅ Image enregistrée : ../../Data/images/Joliflor.png
# ✅ Image enregistrée : ../../Data/images/Marill.png
# ✅ Image enregistrée : ../../Data/images/Azumarill.png
# ✅ Image enregistrée : ../../Data/images/Simularbre.png
# ✅ Image enregistrée : ../../Data/images/Tarpaud.png
# ✅ Image enregistrée : ../../Data/images/Granivol.png
# ✅ Image enregistrée : ../../Data/images/Floravol.png
# ✅ Image enregistrée : ../../Data/images/Cotovol.png
# ✅ Image enregistrée : ../../Data/images/Capumain.png
# ✅ Image enregistrée : ../../Data/images/Tournegrin.png
# ✅ Image enregistrée : ../../Data/images/Héliatronc.png
# ✅ Image enregistrée : ../../Data/images/Yanma.png
# ✅ Image enregistrée : ../../Data/images/Axoloto.png
# ✅ Image enregistrée : ../../Data/images/Maraiste.png
# ✅ Image enregistrée : ../../Data/images/Mentali.png
# ✅ Image enregistrée : ../../Data/images/Noctali.png
# ✅ Image enregistrée : ../../Data/images/Cornèbre.png
# ✅ Image enregistrée : ../../Data/images/Roigada.png
# ✅ Image enregistrée : ../../Data/images/Feuforêve.png
# ✅ Image enregistrée : ../../Data/images/Zarbi.png
# ✅ Image enregistrée : ../../Data/images/Qulbutoké.png
# ✅ Image enregistrée : ../../Data/images/Girafarig.png
# ✅ Image enregistrée : ../../Data/images/Pomdepik.png
# ✅ Image enregistrée : ../../Data/images/Foretress.png
# ✅ Image enregistrée : ../../Data/images/Insolourdo.png
# ✅ Image enregistrée : ../../Data/images/Scorplane.png
# ✅ Image enregistrée : ../../Data/images/Steelix.png
# ✅ Image enregistrée : ../../Data/images/Snubbull.png
# ✅ Image enregistrée : ../../Data/images/Granbull.png
# ✅ Image enregistrée : ../../Data/images/Qwilfish.png
# ✅ Image enregistrée : ../../Data/images/Cizayox.png
# ✅ Image enregistrée : ../../Data/images/Caratroc.png
# ✅ Image enregistrée : ../../Data/images/Scarhino.png
# ✅ Image enregistrée : ../../Data/images/Farfuret.png
# ✅ Image enregistrée : ../../Data/images/Teddiursa.png
# ✅ Image enregistrée : ../../Data/images/Ursaring.png
# ✅ Image enregistrée : ../../Data/images/Limagma.png
# ✅ Image enregistrée : ../../Data/images/Volcaropod.png
# ✅ Image enregistrée : ../../Data/images/Marcacrin.png
# ✅ Image enregistrée : ../../Data/images/Cochignon.png
# ✅ Image enregistrée : ../../Data/images/Corayon.png
# ✅ Image enregistrée : ../../Data/images/Rémoraid.png
# ✅ Image enregistrée : ../../Data/images/Octillery.png
# ✅ Image enregistrée : ../../Data/images/Cadoizo.png
# ✅ Image enregistrée : ../../Data/images/Démanta.png
# ✅ Image enregistrée : ../../Data/images/Airmure.png
# ✅ Image enregistrée : ../../Data/images/Malosse.png
# ✅ Image enregistrée : ../../Data/images/Démolosse.png
# ✅ Image enregistrée : ../../Data/images/Hyporoi.png
# ✅ Image enregistrée : ../../Data/images/Phanpy.png
# ✅ Image enregistrée : ../../Data/images/Donphan.png
# ✅ Image enregistrée : ../../Data/images/Porygon2.png
# ✅ Image enregistrée : ../../Data/images/Cerfrousse.png
# ✅ Image enregistrée : ../../Data/images/Queulorior.png
# ✅ Image enregistrée : ../../Data/images/Debugant.png
# ✅ Image enregistrée : ../../Data/images/Kapoera.png
# ✅ Image enregistrée : ../../Data/images/Lippouti.png
# ✅ Image enregistrée : ../../Data/images/Élekid.png
# ✅ Image enregistrée : ../../Data/images/Magby.png
# ✅ Image enregistrée : ../../Data/images/Écrémeuh.png
# ✅ Image enregistrée : ../../Data/images/Leuphorie.png
# ✅ Image enregistrée : ../../Data/images/Raikou.png
# ✅ Image enregistrée : ../../Data/images/Entei.png
# ✅ Image enregistrée : ../../Data/images/Suicune.png
# ✅ Image enregistrée : ../../Data/images/Embrylex.png
# ✅ Image enregistrée : ../../Data/images/Ymphect.png
# ✅ Image enregistrée : ../../Data/images/Tyranocif.png
# ✅ Image enregistrée : ../../Data/images/Lugia.png
# ✅ Image enregistrée : ../../Data/images/Ho-Oh.png
# ✅ Image enregistrée : ../../Data/images/Celebi.png
# ✅ Image enregistrée : ../../Data/images/Arcko.png
# ✅ Image enregistrée : ../../Data/images/Massko.png
# ✅ Image enregistrée : ../../Data/images/Jungko.png
# ✅ Image enregistrée : ../../Data/images/Poussifeu.png
# ✅ Image enregistrée : ../../Data/images/Galifeu.png
# ✅ Image enregistrée : ../../Data/images/Braségali.png
# ✅ Image enregistrée : ../../Data/images/Gobou.png
# ✅ Image enregistrée : ../../Data/images/Flobio.png
# ✅ Image enregistrée : ../../Data/images/Laggron.png
# ✅ Image enregistrée : ../../Data/images/Medhyèna.png
# ✅ Image enregistrée : ../../Data/images/Grahyèna.png
# ✅ Image enregistrée : ../../Data/images/Zigzaton.png
# ✅ Image enregistrée : ../../Data/images/Linéon.png
# ✅ Image enregistrée : ../../Data/images/Chenipotte.png
# ✅ Image enregistrée : ../../Data/images/Armulys.png
# ✅ Image enregistrée : ../../Data/images/Charmillon.png
# ✅ Image enregistrée : ../../Data/images/Blindalys.png
# ✅ Image enregistrée : ../../Data/images/Papinox.png
# ✅ Image enregistrée : ../../Data/images/Nénupiot.png
# ✅ Image enregistrée : ../../Data/images/Lombre.png
# ✅ Image enregistrée : ../../Data/images/Ludicolo.png
# ✅ Image enregistrée : ../../Data/images/Grainipiot.png
# ✅ Image enregistrée : ../../Data/images/Pifeuil.png
# ✅ Image enregistrée : ../../Data/images/Tengalice.png
# ✅ Image enregistrée : ../../Data/images/Nirondelle.png
# ✅ Image enregistrée : ../../Data/images/Hélédelle.png
# ✅ Image enregistrée : ../../Data/images/Goélise.png
# ✅ Image enregistrée : ../../Data/images/Bekipan.png
# ✅ Image enregistrée : ../../Data/images/Tarsal.png
# ✅ Image enregistrée : ../../Data/images/Kirlia.png
# ✅ Image enregistrée : ../../Data/images/Gardevoir.png
# ✅ Image enregistrée : ../../Data/images/Arakdo.png
# ✅ Image enregistrée : ../../Data/images/Maskadra.png
# ✅ Image enregistrée : ../../Data/images/Balignon.png
# ✅ Image enregistrée : ../../Data/images/Chapignon.png
# ✅ Image enregistrée : ../../Data/images/Parecool.png
# ✅ Image enregistrée : ../../Data/images/Vigoroth.png
# ✅ Image enregistrée : ../../Data/images/Monaflèmit.png
# ✅ Image enregistrée : ../../Data/images/Ningale.png
# ✅ Image enregistrée : ../../Data/images/Ninjask.png
# ✅ Image enregistrée : ../../Data/images/Munja.png
# ✅ Image enregistrée : ../../Data/images/Chuchmur.png
# ✅ Image enregistrée : ../../Data/images/Ramboum.png
# ✅ Image enregistrée : ../../Data/images/Brouhabam.png
# ✅ Image enregistrée : ../../Data/images/Makuhita.png
# ✅ Image enregistrée : ../../Data/images/Hariyama.png
# ✅ Image enregistrée : ../../Data/images/Azurill.png
# ✅ Image enregistrée : ../../Data/images/Tarinor.png
# ✅ Image enregistrée : ../../Data/images/Skitty.png
# ✅ Image enregistrée : ../../Data/images/Delcatty.png
# ✅ Image enregistrée : ../../Data/images/Ténéfix.png
# ✅ Image enregistrée : ../../Data/images/Mysdibule.png
# ✅ Image enregistrée : ../../Data/images/Galekid.png
# ✅ Image enregistrée : ../../Data/images/Galegon.png
# ✅ Image enregistrée : ../../Data/images/Galeking.png
# ✅ Image enregistrée : ../../Data/images/Méditikka.png
# ✅ Image enregistrée : ../../Data/images/Charmina.png
# ✅ Image enregistrée : ../../Data/images/Dynavolt.png
# ✅ Image enregistrée : ../../Data/images/Élecsprint.png
# ✅ Image enregistrée : ../../Data/images/Posipi.png
# ✅ Image enregistrée : ../../Data/images/Négapi.png
# ✅ Image enregistrée : ../../Data/images/Muciole.png
# ✅ Image enregistrée : ../../Data/images/Lumivole.png
# ✅ Image enregistrée : ../../Data/images/Rosélia.png
# ✅ Image enregistrée : ../../Data/images/Gloupti.png
# ✅ Image enregistrée : ../../Data/images/Avaltout.png
# ✅ Image enregistrée : ../../Data/images/Carvanha.png
# ✅ Image enregistrée : ../../Data/images/Sharpedo.png
# ✅ Image enregistrée : ../../Data/images/Wailmer.png
# ✅ Image enregistrée : ../../Data/images/Wailord.png
# ✅ Image enregistrée : ../../Data/images/Chamallot.png
# ✅ Image enregistrée : ../../Data/images/Camérupt.png
# ✅ Image enregistrée : ../../Data/images/Chartor.png
# ✅ Image enregistrée : ../../Data/images/Spoink.png
# ✅ Image enregistrée : ../../Data/images/Groret.png
# ✅ Image enregistrée : ../../Data/images/Spinda.png
# ✅ Image enregistrée : ../../Data/images/Kraknoix.png
# ✅ Image enregistrée : ../../Data/images/Vibraninf.png
# ✅ Image enregistrée : ../../Data/images/Libégon.png
# ✅ Image enregistrée : ../../Data/images/Cacnea.png
# ✅ Image enregistrée : ../../Data/images/Cacturne.png
# ✅ Image enregistrée : ../../Data/images/Tylton.png
# ✅ Image enregistrée : ../../Data/images/Altaria.png
# ✅ Image enregistrée : ../../Data/images/Mangriff.png
# ✅ Image enregistrée : ../../Data/images/Séviper.png
# ✅ Image enregistrée : ../../Data/images/Séléroc.png
# ✅ Image enregistrée : ../../Data/images/Solaroc.png
# ✅ Image enregistrée : ../../Data/images/Barloche.png
# ✅ Image enregistrée : ../../Data/images/Barbicha.png
# ✅ Image enregistrée : ../../Data/images/Écrapince.png
# ✅ Image enregistrée : ../../Data/images/Colhomard.png
# ✅ Image enregistrée : ../../Data/images/Balbuto.png
# ✅ Image enregistrée : ../../Data/images/Kaorine.png
# ✅ Image enregistrée : ../../Data/images/Lilia.png
# ✅ Image enregistrée : ../../Data/images/Vacilys.png
# ✅ Image enregistrée : ../../Data/images/Anorith.png
# ✅ Image enregistrée : ../../Data/images/Armaldo.png
# ✅ Image enregistrée : ../../Data/images/Barpau.png
# ✅ Image enregistrée : ../../Data/images/Milobellus.png
# ✅ Image enregistrée : ../../Data/images/Morphéo.png
# ✅ Image enregistrée : ../../Data/images/Kecleon.png
# ✅ Image enregistrée : ../../Data/images/Polichombr.png
# ✅ Image enregistrée : ../../Data/images/Branette.png
# ✅ Image enregistrée : ../../Data/images/Skelénox.png
# ✅ Image enregistrée : ../../Data/images/Téraclope.png
# ✅ Image enregistrée : ../../Data/images/Tropius.png
# ✅ Image enregistrée : ../../Data/images/Éoko.png
# ✅ Image enregistrée : ../../Data/images/Absol.png
# ✅ Image enregistrée : ../../Data/images/Okéoké.png
# ✅ Image enregistrée : ../../Data/images/Stalgamin.png
# ✅ Image enregistrée : ../../Data/images/Oniglali.png
# ✅ Image enregistrée : ../../Data/images/Obalie.png
# ✅ Image enregistrée : ../../Data/images/Phogleur.png
# ✅ Image enregistrée : ../../Data/images/Kaimorse.png
# ✅ Image enregistrée : ../../Data/images/Coquiperl.png
# ✅ Image enregistrée : ../../Data/images/Serpang.png
# ✅ Image enregistrée : ../../Data/images/Rosabyss.png
# ✅ Image enregistrée : ../../Data/images/Relicanth.png
# ✅ Image enregistrée : ../../Data/images/Lovdisc.png
# ✅ Image enregistrée : ../../Data/images/Draby.png
# ✅ Image enregistrée : ../../Data/images/Drackhaus.png
# ✅ Image enregistrée : ../../Data/images/Drattak.png
# ✅ Image enregistrée : ../../Data/images/Terhal.png
# ✅ Image enregistrée : ../../Data/images/Métang.png
# ✅ Image enregistrée : ../../Data/images/Métalosse.png
# ✅ Image enregistrée : ../../Data/images/Regirock.png
# ✅ Image enregistrée : ../../Data/images/Regice.png
# ✅ Image enregistrée : ../../Data/images/Registeel.png
# ✅ Image enregistrée : ../../Data/images/Latias.png
# ✅ Image enregistrée : ../../Data/images/Latios.png
# ✅ Image enregistrée : ../../Data/images/Kyogre.png
# ✅ Image enregistrée : ../../Data/images/Groudon.png
# ✅ Image enregistrée : ../../Data/images/Rayquaza.png
# ✅ Image enregistrée : ../../Data/images/Jirachi.png
# ✅ Image enregistrée : ../../Data/images/Deoxys.png
# ✅ Image enregistrée : ../../Data/images/Tortipouss.png
# ✅ Image enregistrée : ../../Data/images/Boskara.png
# ✅ Image enregistrée : ../../Data/images/Torterra.png
# ✅ Image enregistrée : ../../Data/images/Ouisticram.png
# ✅ Image enregistrée : ../../Data/images/Chimpenfeu.png
# ✅ Image enregistrée : ../../Data/images/Simiabraz.png
# ✅ Image enregistrée : ../../Data/images/Tiplouf.png
# ✅ Image enregistrée : ../../Data/images/Prinplouf.png
# ✅ Image enregistrée : ../../Data/images/Pingoléon.png
# ✅ Image enregistrée : ../../Data/images/Étourmi.png
# ✅ Image enregistrée : ../../Data/images/Étourvol.png
# ✅ Image enregistrée : ../../Data/images/Étouraptor.png
# ✅ Image enregistrée : ../../Data/images/Keunotor.png
# ✅ Image enregistrée : ../../Data/images/Castorno.png
# ✅ Image enregistrée : ../../Data/images/Crikzik.png
# ✅ Image enregistrée : ../../Data/images/Mélokrik.png
# ✅ Image enregistrée : ../../Data/images/Lixy.png
# ✅ Image enregistrée : ../../Data/images/Luxio.png
# ✅ Image enregistrée : ../../Data/images/Luxray.png
# ✅ Image enregistrée : ../../Data/images/Rozbouton.png
# ✅ Image enregistrée : ../../Data/images/Roserade.png
# ✅ Image enregistrée : ../../Data/images/Kranidos.png
# ✅ Image enregistrée : ../../Data/images/Charkos.png
# ✅ Image enregistrée : ../../Data/images/Dinoclier.png
# ✅ Image enregistrée : ../../Data/images/Bastiodon.png
# ✅ Image enregistrée : ../../Data/images/Cheniti.png
# ✅ Image enregistrée : ../../Data/images/Cheniselle.png
# ✅ Image enregistrée : ../../Data/images/Papilord.png
# ✅ Image enregistrée : ../../Data/images/Apitrini.png
# ✅ Image enregistrée : ../../Data/images/Apireine.png
# ✅ Image enregistrée : ../../Data/images/Pachirisu.png
# ✅ Image enregistrée : ../../Data/images/Mustébouée.png
# ✅ Image enregistrée : ../../Data/images/Mustéflott.png
# ✅ Image enregistrée : ../../Data/images/Ceribou.png
# ✅ Image enregistrée : ../../Data/images/Ceriflor.png
# ✅ Image enregistrée : ../../Data/images/Sancoki.png
# ✅ Image enregistrée : ../../Data/images/Tritosor.png
# ✅ Image enregistrée : ../../Data/images/Capidextre.png
# ✅ Image enregistrée : ../../Data/images/Baudrive.png
# ✅ Image enregistrée : ../../Data/images/Grodrive.png
# ✅ Image enregistrée : ../../Data/images/Laporeille.png
# ✅ Image enregistrée : ../../Data/images/Lockpin.png
# ✅ Image enregistrée : ../../Data/images/Magirêve.png
# ✅ Image enregistrée : ../../Data/images/Corboss.png
# ✅ Image enregistrée : ../../Data/images/Chaglam.png
# ✅ Image enregistrée : ../../Data/images/Chaffreux.png
# ✅ Image enregistrée : ../../Data/images/Korillon.png
# ✅ Image enregistrée : ../../Data/images/Moufouette.png
# ✅ Image enregistrée : ../../Data/images/Moufflair.png
# ✅ Image enregistrée : ../../Data/images/Archéomire.png
# ✅ Image enregistrée : ../../Data/images/Archéodong.png
# ✅ Image enregistrée : ../../Data/images/Manzaï.png
# ✅ Image enregistrée : ../../Data/images/Mime Jr..png
# ✅ Image enregistrée : ../../Data/images/Ptiravi.png
# ✅ Image enregistrée : ../../Data/images/Pijako.png
# ✅ Image enregistrée : ../../Data/images/Spiritomb.png
# ✅ Image enregistrée : ../../Data/images/Griknot.png
# ✅ Image enregistrée : ../../Data/images/Carmache.png
# ✅ Image enregistrée : ../../Data/images/Carchacrok.png
# ✅ Image enregistrée : ../../Data/images/Goinfrex.png
# ✅ Image enregistrée : ../../Data/images/Riolu.png
# ✅ Image enregistrée : ../../Data/images/Lucario.png
# ✅ Image enregistrée : ../../Data/images/Hippopotas.png
# ✅ Image enregistrée : ../../Data/images/Hippodocus.png
# ✅ Image enregistrée : ../../Data/images/Rapion.png
# ✅ Image enregistrée : ../../Data/images/Drascore.png
# ✅ Image enregistrée : ../../Data/images/Cradopaud.png
# ✅ Image enregistrée : ../../Data/images/Coatox.png
# ✅ Image enregistrée : ../../Data/images/Vortente.png
# ✅ Image enregistrée : ../../Data/images/Écayon.png
# ✅ Image enregistrée : ../../Data/images/Luminéon.png
# ✅ Image enregistrée : ../../Data/images/Babimanta.png
# ✅ Image enregistrée : ../../Data/images/Blizzi.png
# ✅ Image enregistrée : ../../Data/images/Blizzaroi.png
# ✅ Image enregistrée : ../../Data/images/Dimoret.png
# ✅ Image enregistrée : ../../Data/images/Magnézone.png
# ✅ Image enregistrée : ../../Data/images/Coudlangue.png
# ✅ Image enregistrée : ../../Data/images/Rhinastoc.png
# ✅ Image enregistrée : ../../Data/images/Bouldeneu.png
# ✅ Image enregistrée : ../../Data/images/Élekable.png
# ✅ Image enregistrée : ../../Data/images/Maganon.png
# ✅ Image enregistrée : ../../Data/images/Togekiss.png
# ✅ Image enregistrée : ../../Data/images/Yanmega.png
# ✅ Image enregistrée : ../../Data/images/Phyllali.png
# ✅ Image enregistrée : ../../Data/images/Givrali.png
# ✅ Image enregistrée : ../../Data/images/Scorvol.png
# ✅ Image enregistrée : ../../Data/images/Mammochon.png
# ✅ Image enregistrée : ../../Data/images/Porygon-Z.png
# ✅ Image enregistrée : ../../Data/images/Gallame.png
# ✅ Image enregistrée : ../../Data/images/Tarinorme.png
# ✅ Image enregistrée : ../../Data/images/Noctunoir.png
# ✅ Image enregistrée : ../../Data/images/Momartik.png
# ✅ Image enregistrée : ../../Data/images/Motisma.png
# ✅ Image enregistrée : ../../Data/images/Créhelf.png
# ✅ Image enregistrée : ../../Data/images/Créfollet.png
# ✅ Image enregistrée : ../../Data/images/Créfadet.png
# ✅ Image enregistrée : ../../Data/images/Dialga.png
# ✅ Image enregistrée : ../../Data/images/Palkia.png
# ✅ Image enregistrée : ../../Data/images/Heatran.png
# ✅ Image enregistrée : ../../Data/images/Regigigas.png
# ✅ Image enregistrée : ../../Data/images/Giratina.png
# ✅ Image enregistrée : ../../Data/images/Cresselia.png
# ✅ Image enregistrée : ../../Data/images/Phione.png
# ✅ Image enregistrée : ../../Data/images/Manaphy.png
# ✅ Image enregistrée : ../../Data/images/Darkrai.png
# ✅ Image enregistrée : ../../Data/images/Shaymin.png
# ✅ Image enregistrée : ../../Data/images/Arceus.png
# ✅ Image enregistrée : ../../Data/images/Victini.png
# ✅ Image enregistrée : ../../Data/images/Vipélierre.png
# ✅ Image enregistrée : ../../Data/images/Lianaja.png
# ✅ Image enregistrée : ../../Data/images/Majaspic.png
# ✅ Image enregistrée : ../../Data/images/Gruikui.png
# ✅ Image enregistrée : ../../Data/images/Grotichon.png
# ✅ Image enregistrée : ../../Data/images/Roitiflam.png
# ✅ Image enregistrée : ../../Data/images/Moustillon.png
# ✅ Image enregistrée : ../../Data/images/Mateloutre.png
# ✅ Image enregistrée : ../../Data/images/Clamiral.png
# ✅ Image enregistrée : ../../Data/images/Ratentif.png
# ✅ Image enregistrée : ../../Data/images/Miradar.png
# ✅ Image enregistrée : ../../Data/images/Ponchiot.png
# ✅ Image enregistrée : ../../Data/images/Ponchien.png
# ✅ Image enregistrée : ../../Data/images/Mastouffe.png
# ✅ Image enregistrée : ../../Data/images/Chacripan.png
# ✅ Image enregistrée : ../../Data/images/Léopardus.png
# ✅ Image enregistrée : ../../Data/images/Feuillajou.png
# ✅ Image enregistrée : ../../Data/images/Feuiloutan.png
# ✅ Image enregistrée : ../../Data/images/Flamajou.png
# ✅ Image enregistrée : ../../Data/images/Flamoutan.png
# ✅ Image enregistrée : ../../Data/images/Flotajou.png
# ✅ Image enregistrée : ../../Data/images/Flotoutan.png
# ✅ Image enregistrée : ../../Data/images/Munna.png
# ✅ Image enregistrée : ../../Data/images/Mushana.png
# ✅ Image enregistrée : ../../Data/images/Poichigeon.png
# ✅ Image enregistrée : ../../Data/images/Colombeau.png
# ✅ Image enregistrée : ../../Data/images/Déflaisan.png
# ✅ Image enregistrée : ../../Data/images/Zébibron.png
# ✅ Image enregistrée : ../../Data/images/Zéblitz.png
# ✅ Image enregistrée : ../../Data/images/Nodulithe.png
# ✅ Image enregistrée : ../../Data/images/Géolithe.png
# ✅ Image enregistrée : ../../Data/images/Gigalithe.png
# ✅ Image enregistrée : ../../Data/images/Chovsourir.png
# ✅ Image enregistrée : ../../Data/images/Rhinolove.png
# ✅ Image enregistrée : ../../Data/images/Rototaupe.png
# ✅ Image enregistrée : ../../Data/images/Minotaupe.png
# ✅ Image enregistrée : ../../Data/images/Nanméouïe.png
# ✅ Image enregistrée : ../../Data/images/Charpenti.png
# ✅ Image enregistrée : ../../Data/images/Ouvrifier.png
# ✅ Image enregistrée : ../../Data/images/Bétochef.png
# ✅ Image enregistrée : ../../Data/images/Tritonde.png
# ✅ Image enregistrée : ../../Data/images/Batracné.png
# ✅ Image enregistrée : ../../Data/images/Crapustule.png
# ✅ Image enregistrée : ../../Data/images/Judokrak.png
# ✅ Image enregistrée : ../../Data/images/Karaclée.png
# ✅ Image enregistrée : ../../Data/images/Larveyette.png
# ✅ Image enregistrée : ../../Data/images/Couverdure.png
# ✅ Image enregistrée : ../../Data/images/Manternel.png
# ✅ Image enregistrée : ../../Data/images/Venipatte.png
# ✅ Image enregistrée : ../../Data/images/Scobolide.png
# ✅ Image enregistrée : ../../Data/images/Brutapode.png
# ✅ Image enregistrée : ../../Data/images/Doudouvet.png
# ✅ Image enregistrée : ../../Data/images/Farfaduvet.png
# ✅ Image enregistrée : ../../Data/images/Chlorobule.png
# ✅ Image enregistrée : ../../Data/images/Fragilady.png
# ✅ Image enregistrée : ../../Data/images/Bargantua.png
# ✅ Image enregistrée : ../../Data/images/Mascaïman.png
# ✅ Image enregistrée : ../../Data/images/Escroco.png
# ✅ Image enregistrée : ../../Data/images/Crocorible.png
# ✅ Image enregistrée : ../../Data/images/Darumarond.png
# ✅ Image enregistrée : ../../Data/images/Darumacho.png
# ✅ Image enregistrée : ../../Data/images/Maracachi.png
# ✅ Image enregistrée : ../../Data/images/Crabicoque.png
# ✅ Image enregistrée : ../../Data/images/Crabaraque.png
# ✅ Image enregistrée : ../../Data/images/Baggiguane.png
# ✅ Image enregistrée : ../../Data/images/Baggaïd.png
# ✅ Image enregistrée : ../../Data/images/Cryptéro.png
# ✅ Image enregistrée : ../../Data/images/Tutafeh.png
# ✅ Image enregistrée : ../../Data/images/Tutankafer.png
# ✅ Image enregistrée : ../../Data/images/Carapagos.png
# ✅ Image enregistrée : ../../Data/images/Mégapagos.png
# ✅ Image enregistrée : ../../Data/images/Arkéapti.png
# ✅ Image enregistrée : ../../Data/images/Aéroptéryx.png
# ✅ Image enregistrée : ../../Data/images/Miamiasme.png
# ✅ Image enregistrée : ../../Data/images/Miasmax.png
# ✅ Image enregistrée : ../../Data/images/Zorua.png
# ✅ Image enregistrée : ../../Data/images/Zoroark.png
# ✅ Image enregistrée : ../../Data/images/Chinchidou.png
# ✅ Image enregistrée : ../../Data/images/Pashmilla.png
# ✅ Image enregistrée : ../../Data/images/Scrutella.png
# ✅ Image enregistrée : ../../Data/images/Mesmérella.png
# ✅ Image enregistrée : ../../Data/images/Sidérella.png
# ✅ Image enregistrée : ../../Data/images/Nucléos.png
# ✅ Image enregistrée : ../../Data/images/Méios.png
# ✅ Image enregistrée : ../../Data/images/Symbios.png
# ✅ Image enregistrée : ../../Data/images/Couaneton.png
# ✅ Image enregistrée : ../../Data/images/Lakmécygne.png
# ✅ Image enregistrée : ../../Data/images/Sorbébé.png
# ✅ Image enregistrée : ../../Data/images/Sorboul.png
# ✅ Image enregistrée : ../../Data/images/Sorbouboul.png
# ✅ Image enregistrée : ../../Data/images/Vivaldaim.png
# ✅ Image enregistrée : ../../Data/images/Haydaim.png
# ✅ Image enregistrée : ../../Data/images/Emolga.png
# ✅ Image enregistrée : ../../Data/images/Carabing.png
# ✅ Image enregistrée : ../../Data/images/Lançargot.png
# ✅ Image enregistrée : ../../Data/images/Trompignon.png
# ✅ Image enregistrée : ../../Data/images/Gaulet.png
# ✅ Image enregistrée : ../../Data/images/Viskuse.png
# ✅ Image enregistrée : ../../Data/images/Moyade.png
# ✅ Image enregistrée : ../../Data/images/Mamanbo.png
# ✅ Image enregistrée : ../../Data/images/Statitik.png
# ✅ Image enregistrée : ../../Data/images/Mygavolt.png
# ✅ Image enregistrée : ../../Data/images/Grindur.png
# ✅ Image enregistrée : ../../Data/images/Noacier.png
# ✅ Image enregistrée : ../../Data/images/Tic.png
# ✅ Image enregistrée : ../../Data/images/Clic.png
# ✅ Image enregistrée : ../../Data/images/Cliticlic.png
# ✅ Image enregistrée : ../../Data/images/Anchwatt.png
# ✅ Image enregistrée : ../../Data/images/Lampéroie.png
# ✅ Image enregistrée : ../../Data/images/Ohmassacre.png
# ✅ Image enregistrée : ../../Data/images/Lewsor.png
# ✅ Image enregistrée : ../../Data/images/Neitram.png
# ✅ Image enregistrée : ../../Data/images/Funécire.png
# ✅ Image enregistrée : ../../Data/images/Mélancolux.png
# ✅ Image enregistrée : ../../Data/images/Lugulabre.png
# ✅ Image enregistrée : ../../Data/images/Coupenotte.png
# ✅ Image enregistrée : ../../Data/images/Incisache.png
# ✅ Image enregistrée : ../../Data/images/Tranchodon.png
# ✅ Image enregistrée : ../../Data/images/Polarhume.png
# ✅ Image enregistrée : ../../Data/images/Polagriffe.png
# ✅ Image enregistrée : ../../Data/images/Hexagel.png
# ✅ Image enregistrée : ../../Data/images/Escargaume.png
# ✅ Image enregistrée : ../../Data/images/Limaspeed.png
# ✅ Image enregistrée : ../../Data/images/Limonde.png
# ✅ Image enregistrée : ../../Data/images/Kungfouine.png
# ✅ Image enregistrée : ../../Data/images/Shaofouine.png
# ✅ Image enregistrée : ../../Data/images/Drakkarmin.png
# ✅ Image enregistrée : ../../Data/images/Gringolem.png
# ✅ Image enregistrée : ../../Data/images/Golemastoc.png
# ✅ Image enregistrée : ../../Data/images/Scalpion.png
# ✅ Image enregistrée : ../../Data/images/Scalproie.png
# ✅ Image enregistrée : ../../Data/images/Frison.png
# ✅ Image enregistrée : ../../Data/images/Furaiglon.png
# ✅ Image enregistrée : ../../Data/images/Gueriaigle.png
# ✅ Image enregistrée : ../../Data/images/Vostourno.png
# ✅ Image enregistrée : ../../Data/images/Vaututrice.png
# ✅ Image enregistrée : ../../Data/images/Aflamanoir.png
# ✅ Image enregistrée : ../../Data/images/Fermite.png
# ✅ Image enregistrée : ../../Data/images/Solochi.png
# ✅ Image enregistrée : ../../Data/images/Diamat.png
# ✅ Image enregistrée : ../../Data/images/Trioxhydre.png
# ✅ Image enregistrée : ../../Data/images/Pyronille.png
# ✅ Image enregistrée : ../../Data/images/Pyrax.png
# ✅ Image enregistrée : ../../Data/images/Cobaltium.png
# ✅ Image enregistrée : ../../Data/images/Terrakium.png
# ✅ Image enregistrée : ../../Data/images/Viridium.png
# ✅ Image enregistrée : ../../Data/images/Boréas.png
# ✅ Image enregistrée : ../../Data/images/Fulguris.png
# ✅ Image enregistrée : ../../Data/images/Reshiram.png
# ✅ Image enregistrée : ../../Data/images/Zekrom.png
# ✅ Image enregistrée : ../../Data/images/Démétéros.png
# ✅ Image enregistrée : ../../Data/images/Kyurem.png
# ✅ Image enregistrée : ../../Data/images/Keldeo.png
# ✅ Image enregistrée : ../../Data/images/Meloetta.png
# ✅ Image enregistrée : ../../Data/images/Genesect.png
# ✅ Image enregistrée : ../../Data/images/Marisson.png
# ✅ Image enregistrée : ../../Data/images/Boguérisse.png
# ✅ Image enregistrée : ../../Data/images/Blindépique.png
# ✅ Image enregistrée : ../../Data/images/Feunnec.png
# ✅ Image enregistrée : ../../Data/images/Roussil.png
# ✅ Image enregistrée : ../../Data/images/Goupelin.png
# ✅ Image enregistrée : ../../Data/images/Grenousse.png
# ✅ Image enregistrée : ../../Data/images/Croâporal.png
# ✅ Image enregistrée : ../../Data/images/Amphinobi.png
# ✅ Image enregistrée : ../../Data/images/Sapereau.png
# ✅ Image enregistrée : ../../Data/images/Excavarenne.png
# ✅ Image enregistrée : ../../Data/images/Passerouge.png
# ✅ Image enregistrée : ../../Data/images/Braisillon.png
# ✅ Image enregistrée : ../../Data/images/Flambusard.png
# ✅ Image enregistrée : ../../Data/images/Lépidonille.png
# ✅ Image enregistrée : ../../Data/images/Pérégrain.png
# ✅ Image enregistrée : ../../Data/images/Prismillon.png
# ✅ Image enregistrée : ../../Data/images/Hélionceau.png
# ✅ Image enregistrée : ../../Data/images/Némélios.png
# ✅ Image enregistrée : ../../Data/images/Flabébé.png
# ✅ Image enregistrée : ../../Data/images/Floette.png
# ✅ Image enregistrée : ../../Data/images/Florges.png
# ✅ Image enregistrée : ../../Data/images/Cabriolaine.png
# ✅ Image enregistrée : ../../Data/images/Chevroum.png
# ✅ Image enregistrée : ../../Data/images/Pandespiègle.png
# ✅ Image enregistrée : ../../Data/images/Pandarbare.png
# ✅ Image enregistrée : ../../Data/images/Couafarel.png
# ✅ Image enregistrée : ../../Data/images/Psystigri.png
# ✅ Image enregistrée : ../../Data/images/Mistigrix.png
# ✅ Image enregistrée : ../../Data/images/Monorpale.png
# ✅ Image enregistrée : ../../Data/images/Dimoclès.png
# ✅ Image enregistrée : ../../Data/images/Exagide.png
# ✅ Image enregistrée : ../../Data/images/Fluvetin.png
# ✅ Image enregistrée : ../../Data/images/Cocotine.png
# ✅ Image enregistrée : ../../Data/images/Sucroquin.png
# ✅ Image enregistrée : ../../Data/images/Cupcanaille.png
# ✅ Image enregistrée : ../../Data/images/Sepiatop.png
# ✅ Image enregistrée : ../../Data/images/Sepiatroce.png
# ✅ Image enregistrée : ../../Data/images/Opermine.png
# ✅ Image enregistrée : ../../Data/images/Golgopathe.png
# ✅ Image enregistrée : ../../Data/images/Venalgue.png
# ✅ Image enregistrée : ../../Data/images/Kravarech.png
# ✅ Image enregistrée : ../../Data/images/Flingouste.png
# ✅ Image enregistrée : ../../Data/images/Gamblast.png
# ✅ Image enregistrée : ../../Data/images/Galvaran.png
# ✅ Image enregistrée : ../../Data/images/Iguolta.png
# ✅ Image enregistrée : ../../Data/images/Ptyranidur.png
# ✅ Image enregistrée : ../../Data/images/Rexillius.png
# ✅ Image enregistrée : ../../Data/images/Amagara.png
# ✅ Image enregistrée : ../../Data/images/Dragmara.png
# ✅ Image enregistrée : ../../Data/images/Nymphali.png
# ✅ Image enregistrée : ../../Data/images/Brutalibré.png
# ✅ Image enregistrée : ../../Data/images/Dedenne.png
# ✅ Image enregistrée : ../../Data/images/Strassie.png
# ✅ Image enregistrée : ../../Data/images/Mucuscule.png
# ✅ Image enregistrée : ../../Data/images/Colimucus.png
# ✅ Image enregistrée : ../../Data/images/Muplodocus.png
# ✅ Image enregistrée : ../../Data/images/Trousselin.png
# ✅ Image enregistrée : ../../Data/images/Brocélôme.png
# ✅ Image enregistrée : ../../Data/images/Desséliande.png
# ✅ Image enregistrée : ../../Data/images/Pitrouille.png
# ✅ Image enregistrée : ../../Data/images/Banshitrouye.png
# ✅ Image enregistrée : ../../Data/images/Grelaçon.png
# ✅ Image enregistrée : ../../Data/images/Séracrawl.png
# ✅ Image enregistrée : ../../Data/images/Sonistrelle.png
# ✅ Image enregistrée : ../../Data/images/Bruyverne.png
# ✅ Image enregistrée : ../../Data/images/Xerneas.png
# ✅ Image enregistrée : ../../Data/images/Yveltal.png
# ✅ Image enregistrée : ../../Data/images/Zygarde.png
# ✅ Image enregistrée : ../../Data/images/Diancie.png
# ✅ Image enregistrée : ../../Data/images/Hoopa.png
# ✅ Image enregistrée : ../../Data/images/Volcanion.png
# ✅ Image enregistrée : ../../Data/images/Brindibou.png
# ✅ Image enregistrée : ../../Data/images/Efflèche.png
# ✅ Image enregistrée : ../../Data/images/Archéduc.png
# ✅ Image enregistrée : ../../Data/images/Flamiaou.png
# ✅ Image enregistrée : ../../Data/images/Matoufeu.png
# ✅ Image enregistrée : ../../Data/images/Félinferno.png
# ✅ Image enregistrée : ../../Data/images/Otaquin.png
# ✅ Image enregistrée : ../../Data/images/Otarlette.png
# ✅ Image enregistrée : ../../Data/images/Oratoria.png
# ✅ Image enregistrée : ../../Data/images/Picassaut.png
# ✅ Image enregistrée : ../../Data/images/Piclairon.png
# ✅ Image enregistrée : ../../Data/images/Bazoucan.png
# ✅ Image enregistrée : ../../Data/images/Manglouton.png
# ✅ Image enregistrée : ../../Data/images/Argouste.png
# ✅ Image enregistrée : ../../Data/images/Larvibule.png
# ✅ Image enregistrée : ../../Data/images/Chrysapile.png
# ✅ Image enregistrée : ../../Data/images/Lucanon.png
# ✅ Image enregistrée : ../../Data/images/Crabagarre.png
# ✅ Image enregistrée : ../../Data/images/Crabominable.png
# ✅ Image enregistrée : ../../Data/images/Plumeline.png
# ✅ Image enregistrée : ../../Data/images/Bombydou.png
# ✅ Image enregistrée : ../../Data/images/Rubombelle.png
# ✅ Image enregistrée : ../../Data/images/Rocabot.png
# ✅ Image enregistrée : ../../Data/images/Lougaroc.png
# ✅ Image enregistrée : ../../Data/images/Froussardine.png
# ✅ Image enregistrée : ../../Data/images/Vorastérie.png
# ✅ Image enregistrée : ../../Data/images/Prédastérie.png
# ✅ Image enregistrée : ../../Data/images/Tiboudet.png
# ✅ Image enregistrée : ../../Data/images/Bourrinos.png
# ✅ Image enregistrée : ../../Data/images/Araqua.png
# ✅ Image enregistrée : ../../Data/images/Tarenbulle.png
# ✅ Image enregistrée : ../../Data/images/Mimantis.png
# ✅ Image enregistrée : ../../Data/images/Floramantis.png
# ✅ Image enregistrée : ../../Data/images/Spododo.png
# ✅ Image enregistrée : ../../Data/images/Lampignon.png
# ✅ Image enregistrée : ../../Data/images/Tritox.png
# ✅ Image enregistrée : ../../Data/images/Malamandre.png
# ✅ Image enregistrée : ../../Data/images/Nounourson.png
# ✅ Image enregistrée : ../../Data/images/Chelours.png
# ✅ Image enregistrée : ../../Data/images/Croquine.png
# ✅ Image enregistrée : ../../Data/images/Candine.png
# ✅ Image enregistrée : ../../Data/images/Sucreine.png
# ✅ Image enregistrée : ../../Data/images/Guérilande.png
# ✅ Image enregistrée : ../../Data/images/Gouroutan.png
# ✅ Image enregistrée : ../../Data/images/Quartermac.png
# ✅ Image enregistrée : ../../Data/images/Sovkipou.png
# ✅ Image enregistrée : ../../Data/images/Sarmuraï.png
# ✅ Image enregistrée : ../../Data/images/Bacabouh.png
# ✅ Image enregistrée : ../../Data/images/Trépassable.png
# ✅ Image enregistrée : ../../Data/images/Concombaffe.png
# ✅ Image enregistrée : ../../Data/images/Type:0.png
# ✅ Image enregistrée : ../../Data/images/Silvallié.png
# ✅ Image enregistrée : ../../Data/images/Météno.png
# ✅ Image enregistrée : ../../Data/images/Dodoala.png
# ✅ Image enregistrée : ../../Data/images/Boumata.png
# ✅ Image enregistrée : ../../Data/images/Togedemaru.png
# ✅ Image enregistrée : ../../Data/images/Mimiqui.png
# ✅ Image enregistrée : ../../Data/images/Denticrisse.png
# ✅ Image enregistrée : ../../Data/images/Draïeul.png
# ✅ Image enregistrée : ../../Data/images/Sinistrail.png
# ✅ Image enregistrée : ../../Data/images/Bébécaille.png
# ✅ Image enregistrée : ../../Data/images/Écaïd.png
# ✅ Image enregistrée : ../../Data/images/Ékaïser.png
# ✅ Image enregistrée : ../../Data/images/Tokorico.png
# ✅ Image enregistrée : ../../Data/images/Tokopiyon.png
# ✅ Image enregistrée : ../../Data/images/Tokotoro.png
# ✅ Image enregistrée : ../../Data/images/Tokopisco.png
# ✅ Image enregistrée : ../../Data/images/Cosmog.png
# ✅ Image enregistrée : ../../Data/images/Cosmovum.png
# ✅ Image enregistrée : ../../Data/images/Solgaleo.png
# ✅ Image enregistrée : ../../Data/images/Lunala.png
# ✅ Image enregistrée : ../../Data/images/Zéroïd.png
# ✅ Image enregistrée : ../../Data/images/Mouscoto.png
# ✅ Image enregistrée : ../../Data/images/Cancrelove.png
# ✅ Image enregistrée : ../../Data/images/Câblifère.png
# ✅ Image enregistrée : ../../Data/images/Bamboiselle.png
# ✅ Image enregistrée : ../../Data/images/Katagami.png
# ✅ Image enregistrée : ../../Data/images/Engloutyran.png
# ✅ Image enregistrée : ../../Data/images/Necrozma.png
# ✅ Image enregistrée : ../../Data/images/Magearna.png
# ✅ Image enregistrée : ../../Data/images/Marshadow.png
# ✅ Image enregistrée : ../../Data/images/Vémini.png
# ✅ Image enregistrée : ../../Data/images/Mandrillon.png
# ✅ Image enregistrée : ../../Data/images/Ama-Ama.png
# ✅ Image enregistrée : ../../Data/images/Pierroteknik.png
# ✅ Image enregistrée : ../../Data/images/Zeraora.png
# ✅ Image enregistrée : ../../Data/images/Meltan.png
# ✅ Image enregistrée : ../../Data/images/Melmetal.png
# ✅ Image enregistrée : ../../Data/images/Ouistempo.png
# ✅ Image enregistrée : ../../Data/images/Badabouin.png
# ✅ Image enregistrée : ../../Data/images/Gorythmic.png
# ✅ Image enregistrée : ../../Data/images/Flambino.png
# ✅ Image enregistrée : ../../Data/images/Lapyro.png
# ✅ Image enregistrée : ../../Data/images/Pyrobut.png
# ✅ Image enregistrée : ../../Data/images/Larméléon.png
# ✅ Image enregistrée : ../../Data/images/Arrozard.png
# ✅ Image enregistrée : ../../Data/images/Lézargus.png
# ✅ Image enregistrée : ../../Data/images/Rongourmand.png
# ✅ Image enregistrée : ../../Data/images/Rongrigou.png
# ✅ Image enregistrée : ../../Data/images/Minisange.png
# ✅ Image enregistrée : ../../Data/images/Bleuseille.png
# ✅ Image enregistrée : ../../Data/images/Corvaillus.png
# ✅ Image enregistrée : ../../Data/images/Larvadar.png
# ✅ Image enregistrée : ../../Data/images/Coléodôme.png
# ✅ Image enregistrée : ../../Data/images/Astronelle.png
# ✅ Image enregistrée : ../../Data/images/Goupilou.png
# ✅ Image enregistrée : ../../Data/images/Roublenard.png
# ✅ Image enregistrée : ../../Data/images/Tournicoton.png
# ✅ Image enregistrée : ../../Data/images/Blancoton.png
# ✅ Image enregistrée : ../../Data/images/Moumouton.png
# ✅ Image enregistrée : ../../Data/images/Moumouflon.png
# ✅ Image enregistrée : ../../Data/images/Khélocrok.png
# ✅ Image enregistrée : ../../Data/images/Torgamord.png
# ✅ Image enregistrée : ../../Data/images/Voltoutou.png
# ✅ Image enregistrée : ../../Data/images/Fulgudog.png
# ✅ Image enregistrée : ../../Data/images/Charbi.png
# ✅ Image enregistrée : ../../Data/images/Wagomine.png
# ✅ Image enregistrée : ../../Data/images/Monthracite.png
# ✅ Image enregistrée : ../../Data/images/Verpom.png
# ✅ Image enregistrée : ../../Data/images/Pomdrapi.png
# ✅ Image enregistrée : ../../Data/images/Dratatin.png
# ✅ Image enregistrée : ../../Data/images/Dunaja.png
# ✅ Image enregistrée : ../../Data/images/Dunaconda.png
# ✅ Image enregistrée : ../../Data/images/Nigosier.png
# ✅ Image enregistrée : ../../Data/images/Embrochet.png
# ✅ Image enregistrée : ../../Data/images/Hastacuda.png
# ✅ Image enregistrée : ../../Data/images/Toxizap.png
# ✅ Image enregistrée : ../../Data/images/Salarsen.png
# ✅ Image enregistrée : ../../Data/images/Grillepattes.png
# ✅ Image enregistrée : ../../Data/images/Scolocendre.png
# ✅ Image enregistrée : ../../Data/images/Poulpaf.png
# ✅ Image enregistrée : ../../Data/images/Krakos.png
# ✅ Image enregistrée : ../../Data/images/Théffroi.png
# ✅ Image enregistrée : ../../Data/images/Polthégeist.png
# ✅ Image enregistrée : ../../Data/images/Bibichut.png
# ✅ Image enregistrée : ../../Data/images/Chapotus.png
# ✅ Image enregistrée : ../../Data/images/Sorcilence.png
# ✅ Image enregistrée : ../../Data/images/Grimalin.png
# ✅ Image enregistrée : ../../Data/images/Fourbelin.png
# ✅ Image enregistrée : ../../Data/images/Angoliath.png
# ✅ Image enregistrée : ../../Data/images/Ixon.png
# ✅ Image enregistrée : ../../Data/images/Berserkatt.png
# ✅ Image enregistrée : ../../Data/images/Corayôme.png
# ✅ Image enregistrée : ../../Data/images/Palarticho.png
# ✅ Image enregistrée : ../../Data/images/M. Glaquette.png
# ✅ Image enregistrée : ../../Data/images/Tutétékri.png
# ✅ Image enregistrée : ../../Data/images/Crèmy.png
# ✅ Image enregistrée : ../../Data/images/Charmilly.png
# ✅ Image enregistrée : ../../Data/images/Hexadron.png
# ✅ Image enregistrée : ../../Data/images/Wattapik.png
# ✅ Image enregistrée : ../../Data/images/Frissonille.png
# ✅ Image enregistrée : ../../Data/images/Beldeneige.png
# ✅ Image enregistrée : ../../Data/images/Dolman.png
# ✅ Image enregistrée : ../../Data/images/Bekaglaçon.png
# ✅ Image enregistrée : ../../Data/images/Wimessir.png
# ✅ Image enregistrée : ../../Data/images/Morpeko.png
# ✅ Image enregistrée : ../../Data/images/Charibari.png
# ✅ Image enregistrée : ../../Data/images/Pachyradjah.png
# ✅ Image enregistrée : ../../Data/images/Galvagon.png
# ✅ Image enregistrée : ../../Data/images/Galvagla.png
# ✅ Image enregistrée : ../../Data/images/Hydragon.png
# ✅ Image enregistrée : ../../Data/images/Hydragla.png
# ✅ Image enregistrée : ../../Data/images/Duralugon.png
# ✅ Image enregistrée : ../../Data/images/Fantyrm.png
# ✅ Image enregistrée : ../../Data/images/Dispareptil.png
# ✅ Image enregistrée : ../../Data/images/Lanssorien.png
# ✅ Image enregistrée : ../../Data/images/Zacian.png
# ✅ Image enregistrée : ../../Data/images/Zamazenta.png
# ✅ Image enregistrée : ../../Data/images/Éthernatos.png
# ✅ Image enregistrée : ../../Data/images/Wushours.png
# ✅ Image enregistrée : ../../Data/images/Shifours.png
# ✅ Image enregistrée : ../../Data/images/Zarude.png
# ✅ Image enregistrée : ../../Data/images/Regieleki.png
# ✅ Image enregistrée : ../../Data/images/Regidrago.png
# ✅ Image enregistrée : ../../Data/images/Blizzeval.png
# ✅ Image enregistrée : ../../Data/images/Spectreval.png
# ✅ Image enregistrée : ../../Data/images/Sylveroy.png
# ✅ Image enregistrée : ../../Data/images/Cerbyllin.png
# ✅ Image enregistrée : ../../Data/images/Hachécateur.png
# ✅ Image enregistrée : ../../Data/images/Ursaking.png
# ✅ Image enregistrée : ../../Data/images/Paragruel.png
# ✅ Image enregistrée : ../../Data/images/Farfurex.png
# ✅ Image enregistrée : ../../Data/images/Qwilpik.png
# ✅ Image enregistrée : ../../Data/images/Amovénus.png
# ✅ Image enregistrée : ../../Data/images/Poussacha.png
# ✅ Image enregistrée : ../../Data/images/Matourgeon.png
# ✅ Image enregistrée : ../../Data/images/Miascarade.png
# ✅ Image enregistrée : ../../Data/images/Chochodile.png
# ✅ Image enregistrée : ../../Data/images/Crocogril.png
# ✅ Image enregistrée : ../../Data/images/Flâmigator.png
# ✅ Image enregistrée : ../../Data/images/Coiffeton.png
# ✅ Image enregistrée : ../../Data/images/Canarbello.png
# ✅ Image enregistrée : ../../Data/images/Palmaval.png
# ✅ Image enregistrée : ../../Data/images/Gourmelet.png
# ✅ Image enregistrée : ../../Data/images/Fragroin.png
# ✅ Image enregistrée : ../../Data/images/Tissenboule.png
# ✅ Image enregistrée : ../../Data/images/Filentrappe.png
# ✅ Image enregistrée : ../../Data/images/Lilliterelle.png
# ✅ Image enregistrée : ../../Data/images/Gambex.png
# ✅ Image enregistrée : ../../Data/images/Pohm.png
# ✅ Image enregistrée : ../../Data/images/Pohmotte.png
# ✅ Image enregistrée : ../../Data/images/Pohmarmotte.png
# ✅ Image enregistrée : ../../Data/images/Compagnol.png
# ✅ Image enregistrée : ../../Data/images/Famignol.png
# ✅ Image enregistrée : ../../Data/images/Pâtachiot.png
# ✅ Image enregistrée : ../../Data/images/Briochien.png
# ✅ Image enregistrée : ../../Data/images/Olivini.png
# ✅ Image enregistrée : ../../Data/images/Olivado.png
# ✅ Image enregistrée : ../../Data/images/Arboliva.png
# ✅ Image enregistrée : ../../Data/images/Tapatoès.png
# ✅ Image enregistrée : ../../Data/images/Selutin.png
# ✅ Image enregistrée : ../../Data/images/Amassel.png
# ✅ Image enregistrée : ../../Data/images/Gigansel.png
# ✅ Image enregistrée : ../../Data/images/Charbambin.png
# ✅ Image enregistrée : ../../Data/images/Carmadura.png
# ✅ Image enregistrée : ../../Data/images/Malvalame.png
# ✅ Image enregistrée : ../../Data/images/Têtampoule.png
# ✅ Image enregistrée : ../../Data/images/Ampibidou.png
# ✅ Image enregistrée : ../../Data/images/Zapétrel.png
# ✅ Image enregistrée : ../../Data/images/Fulgulairo.png
# ✅ Image enregistrée : ../../Data/images/Grondogue.png
# ✅ Image enregistrée : ../../Data/images/Dogrino.png
# ✅ Image enregistrée : ../../Data/images/Gribouraigne.png
# ✅ Image enregistrée : ../../Data/images/Tag-Tag.png
# ✅ Image enregistrée : ../../Data/images/Virovent.png
# ✅ Image enregistrée : ../../Data/images/Virevorreur.png
# ✅ Image enregistrée : ../../Data/images/Terracool.png
# ✅ Image enregistrée : ../../Data/images/Terracruel.png
# ✅ Image enregistrée : ../../Data/images/Craparoi.png
# ✅ Image enregistrée : ../../Data/images/Pimito.png
# ✅ Image enregistrée : ../../Data/images/Scovilain.png
# ✅ Image enregistrée : ../../Data/images/Léboulérou.png
# ✅ Image enregistrée : ../../Data/images/Bérasca.png
# ✅ Image enregistrée : ../../Data/images/Flotillon.png
# ✅ Image enregistrée : ../../Data/images/Cléopsytra.png
# ✅ Image enregistrée : ../../Data/images/Forgerette.png
# ✅ Image enregistrée : ../../Data/images/Forgella.png
# ✅ Image enregistrée : ../../Data/images/Forgelina.png
# ✅ Image enregistrée : ../../Data/images/Taupikeau.png
# ✅ Image enregistrée : ../../Data/images/Triopikeau.png
# ✅ Image enregistrée : ../../Data/images/Lestombaile.png
# ✅ Image enregistrée : ../../Data/images/Dofin.png
# ✅ Image enregistrée : ../../Data/images/Superdofin.png
# ✅ Image enregistrée : ../../Data/images/Vrombi.png
# ✅ Image enregistrée : ../../Data/images/Vrombotor.png
# ✅ Image enregistrée : ../../Data/images/Motorizard.png
# ✅ Image enregistrée : ../../Data/images/Ferdeter.png
# ✅ Image enregistrée : ../../Data/images/Germéclat.png
# ✅ Image enregistrée : ../../Data/images/Floréclat.png
# ✅ Image enregistrée : ../../Data/images/Toutombe.png
# ✅ Image enregistrée : ../../Data/images/Tomberro.png
# ✅ Image enregistrée : ../../Data/images/Flamenroule.png
# ✅ Image enregistrée : ../../Data/images/Piétacé.png
# ✅ Image enregistrée : ../../Data/images/Balbalèze.png
# ✅ Image enregistrée : ../../Data/images/Délestin.png
# ✅ Image enregistrée : ../../Data/images/Oyacata.png
# ✅ Image enregistrée : ../../Data/images/Nigirigon.png
# ✅ Image enregistrée : ../../Data/images/Courrousinge.png
# ✅ Image enregistrée : ../../Data/images/Terraiste.png
# ✅ Image enregistrée : ../../Data/images/Farigiraf.png
# ✅ Image enregistrée : ../../Data/images/Deusolourdo.png
# ✅ Image enregistrée : ../../Data/images/Scalpereur.png
# ✅ Image enregistrée : ../../Data/images/Fort-Ivoire.png
# ✅ Image enregistrée : ../../Data/images/Hurle-Queue.png
# ✅ Image enregistrée : ../../Data/images/Fongus-Furie.png
# ✅ Image enregistrée : ../../Data/images/Flotte-Mèche.png
# ✅ Image enregistrée : ../../Data/images/Rampe-Ailes.png
# ✅ Image enregistrée : ../../Data/images/Pelage-Sablé.png
# ✅ Image enregistrée : ../../Data/images/Roue-de-Fer.png
# ✅ Image enregistrée : ../../Data/images/Hotte-de-Fer.png
# ✅ Image enregistrée : ../../Data/images/Paume-de-Fer.png
# ✅ Image enregistrée : ../../Data/images/Têtes-de-Fer.png
# ✅ Image enregistrée : ../../Data/images/Mite-de-Fer.png
# ✅ Image enregistrée : ../../Data/images/Épine-de-Fer.png
# ✅ Image enregistrée : ../../Data/images/Frigodo.png
# ✅ Image enregistrée : ../../Data/images/Cryodo.png
# ✅ Image enregistrée : ../../Data/images/Glaivodo.png
# ✅ Image enregistrée : ../../Data/images/Mordudor.png
# ✅ Image enregistrée : ../../Data/images/Gromago.png
# ✅ Image enregistrée : ../../Data/images/Chongjian.png
# ✅ Image enregistrée : ../../Data/images/Baojian.png
# ✅ Image enregistrée : ../../Data/images/Dinglu.png
# ✅ Image enregistrée : ../../Data/images/Yuyu.png
# ✅ Image enregistrée : ../../Data/images/Rugit-Lune.png
# ✅ Image enregistrée : ../../Data/images/Garde-de-Fer.png
# ✅ Image enregistrée : ../../Data/images/Koraidon.png
# ✅ Image enregistrée : ../../Data/images/Miraidon.png
# ✅ Image enregistrée : ../../Data/images/Serpente-Eau.png
# ✅ Image enregistrée : ../../Data/images/Vert-de-Fer.png
# ✅ Image enregistrée : ../../Data/images/Pomdramour.png
# ✅ Image enregistrée : ../../Data/images/Poltchageist.png
# ✅ Image enregistrée : ../../Data/images/Théffroyable.png
# ✅ Image enregistrée : ../../Data/images/Félicanis.png
# ✅ Image enregistrée : ../../Data/images/Fortusimia.png
# ✅ Image enregistrée : ../../Data/images/Favianos.png
# ✅ Image enregistrée : ../../Data/images/Ogerpon.png
# ✅ Image enregistrée : ../../Data/images/Pondralugon.png
# ✅ Image enregistrée : ../../Data/images/Pomdorochi.png
# ✅ Image enregistrée : ../../Data/images/Feu-Perçant.png
# ✅ Image enregistrée : ../../Data/images/Ire-Foudre.png
# ✅ Image enregistrée : ../../Data/images/Roc-de-Fer.png
# ✅ Image enregistrée : ../../Data/images/Chef-de-Fer.png
# ✅ Image enregistrée : ../../Data/images/Terapagos.png
# ✅ Image enregistrée : ../../Data/images/Pêchaminus.png
